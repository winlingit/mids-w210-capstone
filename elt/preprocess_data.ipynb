# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 75

# %% [markdown]
# ## Campaign Finance
#
# - Raw data split into election years, 1990 - 2016
# - Text fields are surrounded by the pipe character (ascii 124). Date and numeric fields are not.  Commas separate all fields.
# - Data dictionaries and user guide are in raw/campaign_finance

# %% [markdown]
# ### PAC Contributions
# Helpful notes from user guide:
# - In all cases, be sure to set realcode to Not like z9* and Not like z4* to eliminate transfers and joint fund raising committees.
# - To calculate direct contributions to candidates, you limit to DI = D.
# - Note that the FEC every now and then puts PAC to candidate data in the PAC to PAC table –to be thorough, check there as well

# %%
def direct_contributions(year):
    """Read pac contributiontable and keep direct contributions, 
        join with candidate and pac info.
    Args:
        year: election year of data
    Returns:
        dataframe of direct PAC contributions for election year
    """
    
    # read PAC to candidate data
    year = str(int(year))
    file_loc = 'raw/campaign_finance/'
    file_loc += year + "/"
    file_name = 'pacs' + year[-2:] + '.txt'
    names_pacs = ['Cycle','FECRecNo','PACID','CID',
                  'Amount','Date','RealCode','Type',
                  'DI','FECCandID']
    df = pd.read_table(file_loc + file_name, 
                       delimiter=",", 
                       quotechar="|", 
                       names=names_pacs)
    
    # read candidate info
    names_cand = ['Cycle','FECCandID','CID','FirstLastP',
                  'Party','DistIDRunFor','DistIDCurr','CurrCand', 'CycleCand', 
                  'CRPICO', 'RecipCode', 'NoPacs']
    file_name = 'cands' + year[-2:] + '.txt'
    df_cand = pd.read_table(file_loc + file_name, 
                            delimiter=",", 
                            quotechar="|", 
                            names=names_cand)
    
    # filter our presidential candidates and candidates who dropped out
    df_cand = df_cand[df_cand.DistIDRunFor != 'PRES']
    df_cand = df_cand[df_cand.CurrCand == 'Y']
    df_cand.drop_duplicates(subset=['CID'], inplace=True)
    
    # read pac to pac data to be thorough
    # check if there are any direct candidate contributions
    # append to df
    names_ptop = ['Cycle','FECRecNo','Filerid','DonorCmte','ContribLendTrans',
                  'City','State','Zip','FECOccEmp','Primcode','Date','Amount',
                  'RecipID','Party','Otherid','RecipCode','RecipPrimcode','Amend', 
                  'Report', 'PG','Microfilm','Type','RealCode','Source']
    file_name = 'pac_other' + year[-2:] + '.txt'
    df_ptop = pd.read_table(file_loc + file_name, 
                            delimiter=",", 
                            quotechar="|", 
                            names=names_ptop)
    df_ptop = df_ptop[df_ptop.Type.str.startswith('2')]
    df_ptop.dropna(subset = ['RecipID'], inplace = True)
    df_ptop = df_ptop[df_ptop.RecipID.str.startswith('N')]
    df_ptop.rename(columns = {'Filerid':'PACID',
                              'RecipID':'CID',}, inplace = True)
    df_ptop['DI'] = np.nan
    df_ptop = pd.merge(df_ptop, df_cand[['CID','FECCandID']], how = 'left', on = 'CID')
    df_ptop = df_ptop[names_pacs]
    df = pd.concat([df,df_ptop])
    
    # filter data
    df = df[df.RealCode.str.lower().str.startswith('z9') == False]
    df = df[df.RealCode.str.lower().str.startswith('z4') == False]
    df = df[df.DI == 'D']
    
    # join on candidate info
    df.drop('FECCandID', axis = 1, inplace=True)
    df = pd.merge(df, df_cand, how = 'left', on = 'CID')
    df.dropna(subset=['Cycle_y'], inplace=True)
    df.drop('Cycle_y', axis = 1, inplace=True)
    df.rename(columns={'Cycle_x': 'Cycle'}, inplace = True)
    
    # read in PAC information
    names_cmtes = ['Cycle', 'CmteID', 'PACShort', 'Affiliate', 'Ultorg',
                   'RecipID', 'RecipCode','FECCandID', 'Party', 'PrimCode', 
                   'Source', 'Sensitive', 'Foreign', 'Active']
    file_name = 'cmtes' + year[-2:] + '.txt'
    df_cmtes = pd.read_table(file_loc + file_name, 
                             delimiter=",", 
                             quotechar="|", 
                             names=names_cmtes, 
                             encoding = 'latin1')
    df_cmtes['CandidateCommittee'] = df_cmtes.CmteID != df_cmtes.RecipID
    df_cmtes.rename(columns={'CmteID': 'PACID'}, inplace=True)
    keep = ['PACID', 'PACShort', 'Affiliate', 'Ultorg',
        'PrimCode', 'Source','Sensitive','Foreign',
        'Active','CandidateCommittee']
    df_cmtes = df_cmtes[keep]
    df_cmtes.drop_duplicates(subset=['PACID'], inplace=True)
    df = pd.merge(df, df_cmtes, how = 'left', on = 'PACID')
    return df

# loop through all years and process data
export_path = "preprocessed/campaign_finance/"
dat_years = np.linspace(1990,2016,14)
for i, year in enumerate(dat_years):
    file_name = "pac_direct_" + str(int(year)) + ".csv"
    df_sub = direct_contributions(year)
    df_sub.to_csv(export_path+file_name, index = False)
    if i == 0:
        df = df_sub
    else:
        df = pd.concat([df, df_sub])
file_name = "pac_direct_all.csv"
df.to_csv(export_path+ file_name, index = False)
# Out:
# C:\Users\Steve\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# C:\Users\Steve\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# C:\Users\Steve\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# https://www.opensecrets.org/resources/create/data_doc.php

# %%
test = pd.read_table('raw/lobbying/lob_lobbying.txt',delimiter=",",quotechar="|", encoding = 'latin1')
test.head()
# Out:
#    B035CC2E-6E80-4A58-8E46-A1FBF084C2E4               CARMEN GROUP INC  \
# 0  B035D063-95B9-40EF-8B64-5A9AEA1DD3EA               Alpha Strategies
# 1  B035D8AE-A329-4FF2-9C85-0F0853CDB648  Lindsay, Hart, Neil & Weigler
# 2  B035EFE3-EC72-4D10-A52B-D4C610B86090     Jude Benedict & Associates
# 3  B03629F3-38CE-42D9-B5C8-6369BDEF44E0                  INVACARE CORP
# 4  B0365E79-0C2A-49A4-90F3-E8F00B000C11                     BALL JANIK
#
#             Carmen Group    y                         POLSON, ERIC  \
# 0       Alpha Strategies    y                       Flight Landata
# 1    Lindsay, Hart et al    y                           Timberland
# 2  Jude Benedict & Assoc    y                            OriginOil
# 3          Invacare Corp  NaN                        INVACARE CORP
# 4         Ball Janik LLP    y  OREGON MUSEUM OF SCIENCE & INDUSTRY
#
#                           Polson, Eric                       Polson, Eric.1  \
# 0                       Flight Landata                       Flight Landata
# 1                        Timberland Co                        Timberland Co
# 2                            OriginOil                            OriginOil
# 3                        Invacare Corp                        Invacare Corp
# 4  Oregon Museum of Science & Industry  Oregon Museum of Science & Industry
#
#         0.0  B4000  wda16  n    n.1  .1    2005  mtn  \
# 0       0.0  M9200  webDM  n      n      2010.0  q2n
# 1    5000.0  M3200  Hvr07  n      y   y  2008.0   q3
# 2   10000.0  Y4000         n      y   y  2009.0   q4
# 3  266539.0  H4100  pac    p      n      2006.0    m
# 4   60000.0  X4200  name   n      y   y  2003.0   er
#
#   MID-YEAR TERMINATION (NO ACTIVITY) Unnamed: 17
# 0       SECOND QUARTER (NO ACTIVITY)         NaN
# 1               THIRD QUARTER REPORT         NaN
# 2              FOURTH QUARTER REPORT         NaN
# 3                    MID-YEAR REPORT         NaN
# 4                    YEAR-END REPORT         NaN

# %%
df_cmtes.shape
# Out:
# (17804, 14)

# %%
df.head()
# Out:
#    Cycle_x             FECRecNo      PACID        CID  Amount        Date  \
# 0     2016  4071320161306572461  C00002469  N00033508  5000.0  06/21/2016
# 1     2016  4052020161293006119  C00125641  N00030071  1500.0  04/06/2016
# 2     2016  4101220161340839612  C00331173  N00003682  1000.0  09/15/2016
# 3     2016  4073120151248144443  C00235572  N00002593  5000.0  03/30/2015
# 4     2016  4101320161343026342  C00114025  N00035403  2500.0  09/29/2016
#
#   RealCode Type DI  FECCandID          FirstLastP Party DistIDRunFor  \
# 0    LM100  24K  D  H2CA15094   Eric Swalwell (D)     D         CA15
# 1    C5110  24K  D  H8OR05107   Kurt Schrader (D)     D         OR05
# 2    C5000  24K  D  S0OH00133     Rob Portman (R)     R         OHS2
# 3    J2200  24K  D  S6GA00119  Johnny Isakson (R)     R         GAS2
# 4    B5100  24K  D  H4FL26038  Carlos Curbelo (R)     R         FL26
#
#   DistIDCurr CurrCand CycleCand CRPICO RecipCode NoPacs
# 0       CA15        Y         Y      I        DW
# 1       OR05        Y         Y      I        DW
# 2       OHS2        Y         Y      I        RW
# 3       GAS2        Y         Y      I        RW
# 4       FL26        Y         Y      I        RW

# %%
df.shape
# Out:
# (240242, 19)

# %%
240000 * 14
# Out:
# 3360000

# %%
df[df.CID.duplicated()].shape
# Out:
# (0, 12)

# %%
df[df.CID.duplicated()].sort_values('CID')
# Out:
#       Cycle  FECCandID        CID                       FirstLastP Party  \
# 7408   2016  H6MA07101  N00000270                    Ed Markey (D)     D
# 5226   2016  H8NJ03073  N00000781             Frank Pallone Jr (D)     D
# 5975   2016  H0NJ01066  N00000826             Robert E Andrews (D)     D
# 5018   2016  H6NJ12144  N00000860                    Rush Holt (D)     D
# 7697   2016  H6PA14184  N00001373                   Mike Doyle (D)     D
# 7652   2016  H6PA14176  N00001373                   Mike Doyle (D)     D
# 6841   2016  S4IL00404  N00001885                   Alan Keyes (R)     R
# 3961   2016  P80005580  N00002526                     Bob Barr (R)     R
# 3232   2016  H6ID02191  N00002776              Richard Grayson (D)     D
# 5079   2016  H8AZ06012  N00002776              Richard Grayson (D)     D
# 4096   2016  S2AZ00158  N00002776              Richard Grayson (D)     D
# 7428   2016  S6OH00254  N00003730               Ted Strickland (D)     D
# 5323   2016  H8WI00018  N00004367                Tammy Baldwin (D)     D
# 3089   2016  H0IL08033  N00004766              Robert Marshall (D)     D
# 4704   2016  H4PA11052  N00005092           Andrew J Ostrowski (I)     D
# 1684   2016  S6PA00282  N00005092           Andrew J Ostrowski (I)     I
# 7410   2016  H6MO07128  N00005195                    Roy Blunt (R)     R
# 5056   2016  H6TX22143  N00005918               Steve Stockman (R)     R
# 3936   2016  S6AZ00340  N00006159                   Gary Swing (3)     3
# 4449   2016  S8CO00099  N00006159                   Gary Swing (3)     3
# 7412   2016  H6NM02077  N00006581                 Greg Sowards (R)     R
# 7084   2016  H0CA33109  N00006700                 Mervin Evans (D)     D
# 5492   2016  P60003175  N00006887  Timothy Charles Kalemkarian (R)     R
# 5689   2016  H0CA23043  N00006887  Timothy Charles Kalemkarian (R)     R
# 4955   2016  H6CA42099  N00007089                     Joe Baca (D)     D
# 7646   2016  S6CA00667  N00007286                   Phil Wyman (R)     R
# 5329   2016  P00000679  N00007498           Jerry Leon Carroll (3)     3
# 7332   2016  S8CO00172  N00008051                   Mark Udall (D)     D
# 7707   2016  S6CA00691  N00008274              Loretta Sanchez (D)     D
# 5659   2016  H0AZ01184  N00009573                   Jeff Flake (R)     R
# ...     ...        ...        ...                              ...   ...
# 2965   2016  H00000001  N00038582              Salinas, Xavier (R)     R
# 3125   2016  H6FL18162  N00038631                    Rick Roth (R)     R
# 3126   2016  H6FL26025  N00038632              Valencia Larose (D)     D
# 3200   2016  H6NC06115  N00038720              Jeffrey Roseman (D)     I
# 1589   2016  H6TX06187  N00038720              Jeffrey Roseman (I)     I
# 3202   2016  H6NC06131  N00038721                  Jim Roberts (D)     D
# 1590   2016  H6TX06203  N00038798               Ruby Woolridge (D)     D
# 1196   2016  H6TX19172  N00038818               DeRenda Warren (R)     R
# 1217   2016  H6TX34031  N00038840              Rey Gonzalez Jr (R)     R
# 1545   2016  H6MN02206  N00039129              Gene Rechtzigel (R)     R
# 1656   2016  S6MD03672  N00039234            Elizabeth Croydon (3)     3
# 1674   2016  H6WV01087  N00039270               Mike Manypenny (D)     D
# 3761   2016  H8MN07078  N00039308                  Dave Hughes (R)     R
# 3851   2016  H6NE01127  N00039405                   Daniel Wik (D)     D
# 2650   2016  S6GA00242  N00039476            Mary Kay Bacallao (R)     R
# 3809   2016  H8CA34100  N00039493            Ramon Barajas III (R)     R
# 1740   2016  H8MD00039  N00039532         Matthew Kalus Thaler (R)     R
# 373    2016  H6NV03154  N00039555              Steve Schiffman (D)     D
# 3484   2016  H6AZ09077  N00039651                   Axel Bello (I)     I
# 2677   2016  H6NC01116  N00039686               J.J. Summerell (L)     L
# 2680   2016  H6NC02171  N00039689                  Steve Hight (D)     D
# 2705   2016  H6VA04079  N00039714              Jackee Gonzalez (R)     R
# 534    2016  H6CA51090  N00039768                 Juan Mercado (D)     D
# 772    2016  H6MI09203  N00039795                  Chris Morse (R)     R
# 791    2016  H6NJ11146  N00039815                   Joe Wenzel (D)     D
# 422    2016  H6MO07284  N00039960                   Mary Byrne (R)     R
# 865    2016  S6FL00475  N00040011          Robert Ingram Burke (I)     I
# 3885   2016  H6HI01287  N00040140              Shirlene Ostrov (R)     R
# 3906   2016  H6PA10141  N00040143              Mike Molesevich (D)     D
# 3557   2016  S6AZ00407  N00040488                   Gene Scott (I)     I
#
#      DistIDRunFor DistIDCurr CurrCand CycleCand CRPICO RecipCode NoPacs
# 7408         MAS2                                    I        DI
# 5226         NJ06       NJ06        Y         Y      I        DW
# 5975         NJ01                                             DN
# 5018         NJ12                                             DN
# 7697         PA14                                    I        DI
# 7652         PA14                                    I        DI
# 6841         ILS2                             Y      C        RC
# 3961         GA11                                             RN
# 3232         ID02                             Y      C        DN
# 5079         ID02                                    C        DC
# 4096         ID02                                    C        DC
# 7428         OHS2                   Y         Y      C        DL
# 5323         WIS1                                    I        DI
# 3089         IL06                             Y      C        DL
# 4704         PAS1                                    C        3C
# 1684         PAS1                   Y         Y      C        3L
# 7410         MOS1                                    I        RI
# 5056         TXS1                                             RN
# 3936         AZ02                                    C        3C
# 4449         AZ02                                    C        3C
# 7412         NMS1                                             RN
# 7084         CAS1                                    O        DO
# 5492         CAS1                                    O        RO
# 5689         CAS1                                    O        RO
# 4955         CA31                             Y      C        RL
# 7646         CAS1                             Y      O        RL
# 5329         CAS1                                             3O
# 7332         COS2                                             DN
# 7707         CAS1       CA46        Y         Y      O        DL
# 5659         AZS2                                    I        RI
# ...           ...        ...      ...       ...    ...       ...    ...
# 2965         TX15                                    O        RL
# 3125         FL18                             Y      O        RN
# 3126         FL19                                    C        DC
# 3200         TX06                                    C        DC
# 1589         TX06                                    C        DC
# 3202         NC05                             Y      C        DL
# 1590         TX06                                    C        DC
# 1196         TX19                             Y      O        RL
# 1217         TX34                                    C        RC
# 1545         MN04                                    C        RC
# 1656         MDS2                   Y         Y      O        3L
# 1674         WV01                   Y         Y      C        DL
# 3761         MN07                                    C        RL
# 3851         NE01                                             DC
# 2650         GAS2                                    C        RL
# 3809         CA27                                    C        RN
# 1740         MD02                                    C        DN
# 373          NV03                             Y      O        DL
# 3484         AZ09                   Y         Y      C        3L
# 2677         NC01                   Y         Y      C        3L
# 2680         NC02                             Y      C        DL
# 2705         VA04                             Y      O        RL
# 534          CA51                                    C        DC
# 772          MI09                                    C        RC
# 791          NJ11                                    C        DC
# 422          MO07                                    C        RC
# 865          FL24                                    C        3C
# 3885         HI01                                    O        RO
# 3906         PA10                                    C        DC
# 3557         AZS0                                    C        3C
#
# [255 rows x 12 columns]

# %%
df.head()
# Out:
#    Cycle  FECCandID        CID         FirstLastP Party DistIDRunFor  \
# 0   2016  H4GA02060  N00035294      Greg Duke (R)     R         GA02
# 1   2016  H4GA02078  N00036257  Vivian Childs (R)     R         GA02
# 2   2016  H4GA04116  N00035798   Thomas Brown (D)     D         GA04
# 3   2016  H4GA04124  N00035862   Thomas Wight (D)     D         GA07
# 4   2016  H4GA06087  N00026160      Tom Price (R)     R         GA06
#
#   DistIDCurr CurrCand CycleCand CRPICO RecipCode NoPacs
# 0                   Y         Y      C        RC
# 1                                             RN
# 2                                             DN
# 3                                             DN
# 4       GA06        Y         Y      I        RW

# %%
df.drop_duplicates(subset=['CID']).shape
# Out:
# (1373, 10)

# %%
df.dropna(subset=['FECCandID']).drop_duplicates(subset=['CID','FECCandID']).shape
# Out:
# (1498, 10)

# %%
df.shape
# Out:
# (373967, 10)

# %%
df.DI.value_counts()
# Out:
# D    267478
# I    106489
# Name: DI, dtype: int64

# %%
df.head()
# Out:
#    Cycle             FECRecNo      PACID        CID  Amount        Date  \
# 0   2016  4071320161306572461  C00002469  N00033508    5000  06/21/2016
# 1   2016  4052020161293006119  C00125641  N00030071    1500  04/06/2016
# 2   2016  4101220161340839612  C00331173  N00003682    1000  09/15/2016
# 3   2016  4073120151248144443  C00235572  N00002593    5000  03/30/2015
# 4   2016  4101320161343026342  C00114025  N00035403    2500  09/29/2016
#
#   RealCode Type DI  FECCandID
# 0    LM100  24K  D  H2CA15094
# 1    C5110  24K  D  H8OR05107
# 2    C5000  24K  D  S0OH00133
# 3    J2200  24K  D  S6GA00119
# 4    B5100  24K  D  H4FL26038

# %%
df.shape
# Out:
# (373967, 10)

# %%
df.CID.str.startswith('N').shape
# Out:
# (373967,)

# %% [markdown]
# ### Individual Contributions
# - You do not want to include the money listed in the Indivs table going to PACs because it will show up again as contributions from the PAC.  So, limit the money counted from Indivs:
#     - Join Indivs to Cmtes on Indivs.CmteID = Cmtes.CmteID with Indivs.RecipCode not like P*
#     - Note that this will exclude contributions to leadership PACs. If you want to include individual contributions to leadership PACs, do NOT exclude based on Recipcode. Instead, limit to where Indivs.Party is not null and Indivs.Party<>”” (does not equal blank.)Additionally, restrictions are required for the PAC to PAC data because if those PACs getting money from other PACs then turn around and give that money to candidates, that will also result in double counting.
